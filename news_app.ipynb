# %%
from gnews import GNews
import pandas as pd
news = GNews()

# %%
headlines = news.get_news(input())
headlines
# Out:
# Cerner
# [{'title': "Oracle's acquisition of Cerner: The future of healthcare - cerner.com",
#   'description': "Oracle's acquisition of Cerner: The future of healthcare  cerner.comOracle sets lofty national EHR goal with Cerner acquisition  TechTargetOracle closes Cerner acqisition  Mass DeviceOracle closes $28B buy of 'huge growth engine' Cerner  Healthcare DiveLarry Ellison: Oracle will modernize and expand Cerner's Millennium platform  FedScoopView Full Coverage on Google News",
#   'published date': 'Wed, 08 Jun 2022 07:00:00 GMT',
#   'url': 'https://www.cerner.com/perspectives/oracle-acquisition-of-cerner-the-future-of-healthcare',
#   'publisher': {'href': 'https://www.cerner.com', 'title': 'cerner.com'}},
#  {'title': "13 times Oracle Cerner was in the news lately - Becker's Hospital Review",
#   'description': "13 times Oracle Cerner was in the news lately  Becker's Hospital Review",
#   'published date': 'Fri, 01 Jul 2022 15:29:29 GMT',
# ...

# %%
# def url_extract(headlines):
#     url_list = []
#     n = 0
#     while n < len(headlines):
#         url_list.append(headlines[n]['url'])
#         n = n + 1
#     return url_list


# def url2text(url_list):
#     n2 = 0
#     while n2 < len(url_list):
#         print(news.get_full_article(n2))

headlines = news.get_news(input())


def url2text(headlines):
    title = []
    url_list = []
    date = []
    n = 0
    while n < len(headlines):
        title.append(headlines[n]['title'])
        url_list.append(headlines[n]['url'])
        date.append(headlines[n]['published date'])
        n = n+1
    df = pd.DataFrame({'Title': title, 'URL': url_list, 'Date': date})
    df1 = df.sort_values(by= 'Date', ascending=True)
    
    return df1

    
df = url2text(headlines)
df
# Out:
# Cerner
#                                                 Title  \
# 1   13 times Oracle Cerner was in the news lately ...
# 6   VA delays Oracle Cerner EHR rollout for three ...
# 78  Human Growth Hormone Market Size And Forecast ...
# 90                    Why I Chose Cerner - cerner.com
# 98  EHR Vendor Cerner Reports Q1 2022 Revenue Grow...
# ..                                                ...
# 83  Cerner launches new unit focused on life scien...
# 65  Therapy Management Software Market Outlook 202...
# 61  Hospital EMR Systems Market Research With Alls...
# 77  Cloud Based EMR Software Market Set to Witness...
# 57  Embedded Intelligence Market to Witness Huge G...
#
#                                                   URL  \
# 1   https://www.beckershospitalreview.com/ehrs/13-...
# 6   https://www.beckershospitalreview.com/ehrs/va-...
# 78  https://indiandefencenews.info/810816/uncatego...
# 90  https://www.cerner.com/newsroom/why-i-chose-ce...
# ...

# %%
def url2text(news.get_news(input('Cerner'))):
    title = []
    url_list = []
    n = 0
    while n < len(headlines):
        title.append(headlines[n]['title'])
        url_list.append(headlines[n]['url'])
        n = n+1
    df = pd.DataFrame({'Title': title, 'URL': url_list})
    
    return df
# Out:
#   Input In [19]
#     def url2text(news.get_news(input('Cerner'))):
#                      ^
# SyntaxError: invalid syntax

# %%
from datetime import date, timedelta

# %%
today = date.today()
lastweek = today - timedelta(days=7)
today
# Out:
# datetime.date(2022, 7, 6)

# %%
today
# Out:
# datetime.date(2022, 7, 6)

# %%
lastweek
# Out:
# datetime.date(2022, 6, 29)
